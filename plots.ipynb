# %%
import matplotlib.pyplot as plt
import seaborn as sns

from simulation import run_simulation

# %%
n = 1000 # Starting plankton population size.
iters = 100 # Time steps.
L_max = 1 # Size of square domain.

plankton, positions = run_simulation(n, iters, L_max)

starting_x = [p.x_0 for p in plankton]
starting_y = [p.y_0 for p in plankton]

x_positions = [p.x for p in plankton]
y_positions = [p.y for p in plankton]
starting_positions = [p.y_0 for p in plankton]

# %%
sns.scatterplot(x=starting_x, y=starting_y, hue=starting_positions)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=x_positions, y=y_positions, hue=starting_positions)
# Out:
# <Axes: >
