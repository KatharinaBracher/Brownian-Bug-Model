# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv('../models/masha/GDP_4day_NC32/log.csv')

# %%
#d[['loss', 'val_loss']].plot()
plt.figure(figsize=(4,3))
plt.plot(d['loss'][:30], label='training')
plt.plot(d['val_loss'][:30], label='validation')
#plt.title('6 million samples')
plt.xlabel('epoch')
plt.ylabel('nll loss')
plt.legend()
plt.grid(True)
plt.savefig('../figures/loss6mil.pdf', bbox_inches='tight')

# %%
d[['loss', 'val_loss']].plot()
plt.title('25 million, patience 20')
# Out:
# Text(0.5, 1.0, '25 million, patience 20')
