# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv('../models/masha/GDP_4day_NC32/log.csv')

# %%
#d[['loss', 'val_loss']].plot()
plt.plot(d['loss'][:30], label='loss')
plt.plot(d['val_loss'][:30], label='validation loss')
plt.title('6 million samples')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

# %%
d[['loss', 'val_loss']].plot()
plt.title('25 million, patience 20')
# Out:
# Text(0.5, 1.0, '25 million, patience 20')
