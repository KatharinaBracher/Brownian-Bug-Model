# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv('../models/masha/GDP_4day_NC15/log.csv')

# %%
d[['loss', 'val_loss']].plot()
plt.title('10 million')
# Out:
# Text(0.5, 1.0, '10 million')
