# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tloss10k = [2.9057,
2.2846,
1.6023,
0.6570,
-3.3721e-02,
-3.1446e-01,
-8.2916e-01,
-1.4326e+00,
-1.0341e+00,
1.5885,
2.0346]
vloss10k = [2.6963 ,
2.3119,
1.8228,
1.2661,
0.9953,
0.6976,
0.3295,
-1.3873e-01,
-5.0672e-01,
-6.8390e-02,
-7.1758e-01]

# %%
tloss10m=[-5.7511e-01,
0.0249 ,
-2.5786e+00,
-2.4567e+00,
-3.1208e+00,
0.6654,
1.0936,
-2.5393e+00,
-2.6331e+00,
-2.3337e+00,
10.1025]

vloss10m = [1.7003 ,
-2.2632e+00,
-2.9612e+00,
-1.9928e-01,
-4.9662e+00,
3.2869,
-1.4682e+00,
-3.2166e+00,
-3.5244e+00,
 -2.2851e+00,
2.6654]

# %%
plt.plot(tloss10k, label='train')
plt.plot(vloss10k, label='val')
plt.legend()
plt.title('10.000')
plt.show()
plt.plot(tloss10m, label='train')
plt.plot(vloss10m, label='val')
plt.legend()
plt.title('10.000.000')
# Out:
# Text(0.5, 1.0, '10.000.000')
